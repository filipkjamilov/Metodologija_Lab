# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from ipywidgets import FloatSlider
from IPython.display import Math

# %%
%%latex
\begin{align}

\\ I_{f,filt} = HI_f \\

\\ H(i,j) = e ^ \frac{-d(i,j)^2}{f_h^2}\ (1-e ^ \frac{-d(i,j)^2}{f_l^2}) \\

\\ F(u,v) = {\iint \limits_{-\infty}^\infty} f(x,y)e^{-i2\pi(ux+vy)} dxdy\\

\\ F(u,v) = \sum_{m=-\infty}^{\infty} \sum_{n=-\infty}^{\infty} f[m,n] \cdot e^{-i2\pi(umx_0+vny_0)} \\

\\ F(x,y) = {\iint \limits_{-\infty}^\infty} f(u,v)e^{-i2\pi(ux+vy)} dudv\\

\\ F(x,y) = \sum_{m=-\infty}^{\infty} \sum_{n=-\infty}^{\infty} f(m,n) \cdot e^{i2\pi(xmu_0+ynv_0)} \\

\end{align}
# Out:
# \begin{align}
#
# \\ I_{f,filt} = HI_f \\
#
# \\ H(i,j) = e ^ \frac{-d(i,j)^2}{f_h^2}\ (1-e ^ \frac{-d(i,j)^2}{f_l^2}) \\
#
# \\ F(u,v) = {\iint \limits_{-\infty}^\infty} f(x,y)e^{-i2\pi(ux+vy)} dxdy\\
#
# \\ F(u,v) = \sum_{m=-\infty}^{\infty} \sum_{n=-\infty}^{\infty} f[m,n] \cdot e^{-i2\pi(umx_0+vny_0)} \\
#
# \\ F(x,y) = {\iint \limits_{-\infty}^\infty} f(u,v)e^{-i2\pi(ux+vy)} dudv\\
#
# \\ F(x,y) = \sum_{m=-\infty}^{\infty} \sum_{n=-\infty}^{\infty} f(m,n) \cdot e^{i2\pi(xmu_0+ynv_0)} \\
#
# \end{align}

# %%
min=0
max=0
widgets.IntRangeSlider(
    value=[0, 10],
    min=0,
    max=10,
    step=1,
    description='Frequency cutoffs:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)
# Out:
# IntRangeSlider(value=(0, 10), continuous_update=False, description='Frequency cutoffs:', max=10)

# %%
import matplotlib.pyplot as plt

img = plt.imread('bar.tif')
plt.imshow(img)

# %%
function filter = create_filter(nx,ny,d0,d1)
filter = ones(nx,ny);
for i = 0:nx-1
    for j = 0:ny-1
        dist= sqrt((i-nx/2)^2 + (j-ny/2)^2);
        filter(i+1,j+1) = exp(-(dist^2)/(d1^2)).*(1.0-exp(-(dist^2)/(d0^2)));
    end
end
filter(nx/2+1,ny/2+1)=1;
end

im_fft = fftshift(fft2(im));
filtered_image = abs(ifft2(ifftshift(create_filter(nx,ny,i,j).*im_fft)));
# Out:
# Failed to start kernel "Octave". Kernel didn't respond in 60 seconds
# Error Message:
# [MetaKernelApp] ERROR | Exception in message handler:
# Traceback (most recent call last):
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 655, in kernel_info_request
#     content.update(self.kernel_info)
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 648, in kernel_info
#     'language_info': self.language_info,
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\octave_kernel\kernel.py", line 78, in language_info
#     'version': self.language_version,
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\octave_kernel\kernel.py", line 69, in language_version
#     ver = self.octave_engine.eval('version', silent=True)
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\octave_kernel\kernel.py", line 96, in octave_engine
#     logger=self.log)
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\octave_kernel\kernel.py", line 170, in __init__
#     self.executable = self._get_executable()
#   File "C:\Users\Kjamilov\Anaconda3\lib\site-packages\octave_kernel\kernel.py", line 457, in _get_executable
#     raise OSError('octave-cli not found, please see README')
# OSError: octave-cli not found, please see README
# File contains parsing errors:
# 	[line  2]: function filter = create_filter(nx,ny,d0,d1)
# filter = ones(nx,ny);
# for i = 0:nx-1
#     for j = 0:ny-1
#         dist= sqrt((i-nx/2)^2 + (j-ny/2)^2);
#
# Invalid statements: SyntaxError('invalid syntax', ('<string>', 1, 15, 'function filter = create_filter(nx,ny,d0,d1)\n'))
